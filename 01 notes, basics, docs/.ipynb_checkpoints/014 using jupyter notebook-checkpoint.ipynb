# %%
import os
os.listdir(os.getcwd())
# Out:
# ['014 using jupyter notebook.ipynb',
#  '010 file processing.py',
#  '004 functions and conditionals.py',
#  '015.1 supermarkets.xlsx.xlsx',
#  '009 more on functions.py',
#  '011 modules.py',
#  '012 remote mysql usage.py',
#  '003 opeartions with datatypes.py',
#  '015.2 supermarkets.csv.csv',
#  '015.3 supermarkets.json.json',
#  '013 using pandas.ipynb',
#  '015.6 supermarkets-commas-no-headers.txt.txt',
#  '008 list comprehensions.py',
#  '015.5 supermarkets-semi-colons.txt.txt',
#  '005 user input.py',
#  '007 practice.py',
#  '015.4 supermarkets-commas.txt.txt',
#  '006 loops.py',
#  '001 first.py',
#  '.ipynb_checkpoints',
#  '010 fruits.txt',
#  '010 vegetables.txt',
#  '002 datatypes.py',
#  '011 temps_today.csv']

# %%
import pandas

# %%
df1 = pandas.read_csv('015.2 supermarkets.csv.csv')

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json('015.3 supermarkets.json.json')
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pandas.read_excel('015.1 supermarkets.xlsx.xlsx',sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv('015.4 supermarkets-commas.txt.txt')
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv('015.5 supermarkets-semi-colons.txt.txt',sep=';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pandas.read_csv('015.6 supermarkets-commas-no-headers.txt.txt',header=None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns = ['Id', 'Address', 'City','Zip','Country','Name','Employees']
df6
# Out:
#    Id          Address           City               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.set_index('Id')
# Out:
#             Address           City               Zip Country         Name  \
# Id
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# Id
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6
# Out:
#    Id          Address           City               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = df6.set_index('Id')

# %%
df7
# Out:
#             Address           City               Zip Country         Name  \
# Id
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# Id
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index('Id', inplace=True)

# %%
df6
# Out:
#             Address           City               Zip Country         Name  \
# Id
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# Id
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index('Address',inplace=True)
df6
# Out:
#                           City               Zip Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df6.set_index('Name',inplace=True,drop=False)
df6
# Out:
#                       City               Zip Country         Name  Employees
# Name
#  Madeira     San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %%
df7
# Out:
#             Address           City               Zip Country         Name  \
# Id
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# Id
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.loc["3":"4","Country":'Name']
# Out:
#    Country         Name
# Id
# 3      USA  Super River
# 4      USA   Ben's Shop

# %%
df7.loc["3":"4","Country"]
# Out:
# Id
# 3    USA
# 4    USA
# Name: Country, dtype: object

# %%
df7.loc[4,"Country"]
# Out:
# 'USA'

# %%
df7.loc[3:4,"Country"]
# Out:
# Id
# 3    USA
# 4    USA
# Name: Country, dtype: object

# %%
df7.loc[:,"Name"]
print(df7.loc[:,"Name"])
list(df7.loc[:,"Name"])
print(list(df7.loc[:,"Name"]))
# Out:
# Id
# 1        Madeira
# 2    Bready Shop
# 3    Super River
# 4     Ben's Shop
# 5        Sanchez
# 6     Richvalley
# Name: Name, dtype: object
# [' Madeira', 'Bready Shop', 'Super River', "Ben's Shop", 'Sanchez', 'Richvalley']

# %%
df7.iloc[1:3,1:3]
# Out:
#              City               Zip
# Id
# 2   San Francisco          CA 94119
# 3   San Francisco  California 94114

# %%
df7.drop('City',1)
# Out:
#             Address               Zip Country         Name  Employees
# Id
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df7.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='Id')

# %%
df7.columns
# Out:
# Index(['Address', 'City', 'Zip', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df7['Continent']=df7.shape[0]*['North America']
df7
# Out:
#             Address           City               Zip Country         Name  \
# Id
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# Id
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df7.shape
# Out:
# (6, 7)

# %%
df7.shape[0]*['North America']
# Out:
# ['North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America']

# %%
df7
# Out:
#             Address           City               Zip Country         Name  \
# Id
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# Id
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df7['Continent'] = df7['Country'] + ', ' + 'North America'
df7
# Out:
#             Address           City               Zip Country         Name  \
# Id
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees           Continent
# Id
# 1           8  USA, North America
# 2          15  USA, North America
# 3          25  USA, North America
# 4          10  USA, North America
# 5          12  USA, North America
# 6          20  USA, North America

# %%
df7_t = df7.T
df7_t
# Out:
# Id                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# Zip                  CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Id                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# Zip                  CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df7_t[7] = ['3132 Agarwal Street', 'Delhi', 'In 700001', 'India', 'Rohnak Agarwal', 25, 'India, Asia']
df7_t
# Out:
# Id                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# Zip                  CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Id                          4                   5                   6  \
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# Zip                  CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df7 = df7_t.T
df7
# Out:
#                 Address           City               Zip Country  \
# Id
# 1          3666 21st St  San Francisco          CA 94114     USA
# 2        735 Dolores St  San Francisco          CA 94119     USA
# 3           332 Hill St  San Francisco  California 94114     USA
# 4          3995 23rd St  San Francisco          CA 94114     USA
# 5       1056 Sanchez St  San Francisco        California     USA
# 6       551 Alvarado St  San Francisco          CA 94114     USA
# 7   3132 Agarwal Street          Delhi         In 700001   India
#
#               Name Employees           Continent
# Id
# 1          Madeira         8  USA, North America
# 2      Bready Shop        15  USA, North America
# 3      Super River        25  USA, North America
# 4       Ben's Shop        10  USA, North America
# 5          Sanchez        12  USA, North America
# 6       Richvalley        20  USA, North America
# 7   Rohnak Agarwal        25         India, Asia
